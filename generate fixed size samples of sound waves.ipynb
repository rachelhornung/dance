# %%
import pandas as pd
import os.path
import scipy.io.wavfile
import numpy as np
# import cPickle as pkl
# import h5py

# %%
from dance.sampling import subsample_mean as subsample
# from dance.sampling import subsample_nth as subsample

# %%
# reload song list
meta_data = pd.read_csv("song_info_list.csv")
# meta_data = meta_data[:4]

labels_data = pd.read_csv("labels_list.csv")

# %%
# according to https://mediatum.ub.tum.de/doc/1138535/582915.pdf
# at least 15 seconds of a song are required to get accurate classification
def split_wave_to_samples(wave, sampling_rate=44100, sample_length=20, offset=5, downsample_size=100):
    # split the entire wave to windows of size samplig_rate*sample_length, offsets samples by offset*sampling_rate
    # defaults:
    # since different sampling rates are available, we assume a sampling rate of 44100 to get samples of the same size
    # each data sequence should contain roughly 10 seconds of sound
    # only low frequencies will contain information on the beat/rhythm of the song
    sample_size = sampling_rate * sample_length
    offset_size = sampling_rate * offset
    assert int(sampling_rate/downsample_size) == float(float(sampling_rate/downsample_size))
    samples = []
    for o in range(0, wave.shape[0] - sample_size + 1, offset_size):
        samples.append(subsample(wave[o:o+sample_size], downsample_size))
    return np.array(samples), downsample_size

# %%
def generate_samples(meta, labels, offset=5, downsample_size=100, mono_channels=True):
    # for each song, split into multiple samples and assign corresponding label
    data = []
    y = []
    for idx, song in meta.iterrows():
        # reload song list
        if os.path.isfile("songs/" + song["id"] + ".wav"):
            try:
                song_rate, song_wave = scipy.io.wavfile.read("songs/" + song["id"] + ".wav")
                # add file information to df
                meta.loc[idx, "rate"] = song_rate
                t, n = song_wave.shape
                meta.loc[idx, "time"] = t
                meta.loc[idx, "wav_dims"] = n
                song_labels = labels.loc[labels["id"]==song["id"]]
                samples, downsample_size = split_wave_to_samples(song_wave, offset=offset, downsample_size=downsample_size)
                for il, label in song_labels.iterrows():
                    for six, sample in enumerate(samples):
                        if mono_channels:
                            for channel in range(n): 
                                # each channel of the song should contain sufficient 
                                # information to retrieve the dance style
                                data.append({"label": label["label"], 
                                             "idx": six, 
                                             "channel":channel, 
                                             "id":song["id"], 
                                             "sample":sample[:, channel], 
                                             "rate": song_rate/downsample_size})
                        else:
                            data.append({"label": label["label"], 
                                         "idx": six, 
                                         "channel":"summed", 
                                         "id":song["id"], 
                                         "sample":np.sum(sample, axis=1),
                                         "rate": song_rate/downsample_size})
            except ValueError as err:
                pass
                # print(song["id"], "OS error: {0}".format(err))
    return pd.DataFrame(data), meta

# %%
# split data to training, and test
# since songs are randomly selected it's enough to use the first n songs for training
n_training = int(meta_data.shape[0]*0.5)
n_val = int(meta_data.shape[0]*0.2)
train_meta = meta_data[:n_training]
val_meta = meta_data[n_training:n_training+n_val]
test_meta = meta_data[n_training+n_val:]

# %%
# strongly downsampled sound data, separated channels
train_data, train_meta = generate_samples(train_meta, labels_data)
train_data.to_pickle("train_data.pkl")
val_data, val_meta = generate_samples(val_meta, labels_data)
val_data.to_pickle("val_data.pkl")
#train_data.to_csv('train_samples.csv', sep=';')
test_data, test_meta = generate_samples(test_meta, labels_data)
test_data.to_pickle("test_data.pkl")
#test_data.to_csv('test_samples.csv', sep=';')
#with open("train_data.pkl", "w") as f:
#    pkl.dump(train_data, f)
#    pkl.dump(test_data, f)
# Out:
# /usr/lib64/python2.7/site-packages/pandas/core/indexing.py:296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/lib64/python2.7/site-packages/pandas/core/indexing.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# strongly downsampled sound data, summed channels
train_data, train_meta = generate_samples(train_meta, labels_data, mono_channels=False)
train_data.to_pickle("train_data_summed.pkl")
val_data, val_meta = generate_samples(val_meta, labels_data, mono_channels=False)
val_data.to_pickle("val_data_summed.pkl")
test_data, test_meta = generate_samples(test_meta, labels_data, mono_channels=False)
test_data.to_pickle("test_data_summed.pkl")
# Out:
# /usr/lib64/python2.7/site-packages/pandas/core/indexing.py:296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/lib64/python2.7/site-packages/pandas/core/indexing.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# high frequency sound data, separated channels
train_data, train_meta = generate_samples(train_meta, labels_data, downsample_size=4, offset=50)
train_data.to_pickle("train_data_high.pkl")
val_data, val_meta = generate_samples(val_meta, labels_data, downsample_size=4, offset=50)
val_data.to_pickle("val_data_high.pkl")
test_data, test_meta = generate_samples(test_meta, labels_data, downsample_size=4, offset=50)
test_data.to_pickle("test_data_high.pkl")

# %%
# high frequency sound data, summed channels
train_data, train_meta = generate_samples(train_meta, labels_data, downsample_size=4, offset=50, mono_channels=False)
train_data.to_pickle("train_data_summed_high.pkl")
val_data, val_meta = generate_samples(val_meta, labels_data, downsample_size=4, offset=50, mono_channels=False)
val_data.to_pickle("val_data_summed_high.pkl")
test_data, test_meta = generate_samples(test_meta, labels_data, downsample_size=4, offset=50, mono_channels=False)
test_data.to_pickle("test_data_summed_high.pkl")
# Out:
# /usr/lib64/python2.7/site-packages/pandas/core/indexing.py:296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/lib64/python2.7/site-packages/pandas/core/indexing.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# select data that was loaded only
meta_data = meta_data.dropna(axis=0, how="any")
# Out:
#      Unnamed: 0                            youtube_link           id     rate  \
# 0             0  http://youtube.com/watch?v=KpsVD_GyJuc  KpsVD_GyJuc  44100.0
# 1             1  http://youtube.com/watch?v=ciPGSJW7CnY  ciPGSJW7CnY  48000.0
# 2             2  http://youtube.com/watch?v=GxOA5umDN18  GxOA5umDN18  44100.0
# 3             3  http://youtube.com/watch?v=PXSdVXstEAM  PXSdVXstEAM  44100.0
# 4             4  http://youtube.com/watch?v=FgDU17xqNXo  FgDU17xqNXo  48000.0
# 5             5  http://youtube.com/watch?v=6VgG4zl2QTg  6VgG4zl2QTg  44100.0
# 6             6  http://youtube.com/watch?v=LoyZpt4HFMY  LoyZpt4HFMY  48000.0
# 7             7  http://youtube.com/watch?v=4Gs_pVBeVYo  4Gs_pVBeVYo  44100.0
# 8             8  http://youtube.com/watch?v=vtCHTii1BMs  vtCHTii1BMs  44100.0
# 9             9  http://youtube.com/watch?v=SwJVBq2lwzI  SwJVBq2lwzI  48000.0
# 10           10  http://youtube.com/watch?v=i4lpAuGqr2w  i4lpAuGqr2w  44100.0
# 11           11  http://youtube.com/watch?v=2IrhPpyAEWM  2IrhPpyAEWM  48000.0
# 12           12  http://youtube.com/watch?v=_X84h81XPCM  _X84h81XPCM  44100.0
# 13           13  http://youtube.com/watch?v=soeuEAGLxOc  soeuEAGLxOc  44100.0
# 14           14  http://youtube.com/watch?v=i5De19nvdAM  i5De19nvdAM  48000.0
# 16           16  http://youtube.com/watch?v=11xzO5WrCBI  11xzO5WrCBI  48000.0
# 17           17  http://youtube.com/watch?v=VfLTNFJFapI  VfLTNFJFapI  44100.0
# 18           18  http://youtube.com/watch?v=m5xJK4UVw2A  m5xJK4UVw2A  44100.0
# 19           19  http://youtube.com/watch?v=vCHdH3LiUS4  vCHdH3LiUS4  48000.0
# 21           21  http://youtube.com/watch?v=NZkM_nOJ3d4  NZkM_nOJ3d4  48000.0
# 23           23  http://youtube.com/watch?v=sCYgYv4zyeQ  sCYgYv4zyeQ  48000.0
# 24           24  http://youtube.com/watch?v=DAOT-JVFuZ0  DAOT-JVFuZ0  44100.0
# 25           25  http://youtube.com/watch?v=1aulfl1-ZAM  1aulfl1-ZAM  48000.0
# 28           28  http://youtube.com/watch?v=LQYwZdioa5o  LQYwZdioa5o  44100.0
# 29           29  http://youtube.com/watch?v=vqHEMuyYIb4  vqHEMuyYIb4  48000.0
# 30           30  http://youtube.com/watch?v=OnPXHmaLLeM  OnPXHmaLLeM  48000.0
# 32           32  http://youtube.com/watch?v=5tBCyese4_g  5tBCyese4_g  48000.0
# 33           33  http://youtube.com/watch?v=09dQmeB_NgU  09dQmeB_NgU  48000.0
# 34           34  http://youtube.com/watch?v=PoTWu87G-KU  PoTWu87G-KU  44100.0
# 35           35  http://youtube.com/watch?v=1iAA-2P4Yy4  1iAA-2P4Yy4  44100.0
# ..          ...                                     ...          ...      ...
# 899         899  http://youtube.com/watch?v=MeVSbOF18B4  MeVSbOF18B4  44100.0
# 900         900  http://youtube.com/watch?v=dJ_YjUezWZY  dJ_YjUezWZY  44100.0
# 901         901  http://youtube.com/watch?v=2DjH1wAp1M0  2DjH1wAp1M0  44100.0
# 902         902  http://youtube.com/watch?v=pMXZFIWBAQs  pMXZFIWBAQs  48000.0
# 903         903  http://youtube.com/watch?v=UVg9TZbNZmE  UVg9TZbNZmE  48000.0
# 906         906  http://youtube.com/watch?v=iaaP7U98cjI  iaaP7U98cjI  48000.0
# 907         907  http://youtube.com/watch?v=0ZSzZWzDRWU  0ZSzZWzDRWU  48000.0
# 908         908  http://youtube.com/watch?v=kiRm7Clgi4U  kiRm7Clgi4U  48000.0
# 909         909  http://youtube.com/watch?v=1AZnoDvp3K0  1AZnoDvp3K0  48000.0
# 911         911  http://youtube.com/watch?v=SVy2vPv2IXI  SVy2vPv2IXI  44100.0
# 912         912  http://youtube.com/watch?v=yjW2rrK5vRU  yjW2rrK5vRU  44100.0
# 913         913  http://youtube.com/watch?v=T0EDCAVsEDM  T0EDCAVsEDM  48000.0
# 914         914  http://youtube.com/watch?v=X-o3JQ-6uPc  X-o3JQ-6uPc  48000.0
# 915         915  http://youtube.com/watch?v=1AIu7SqX_UI  1AIu7SqX_UI  48000.0
# 916         916  http://youtube.com/watch?v=IVF0zcqr9Dg  IVF0zcqr9Dg  44100.0
# 917         917  http://youtube.com/watch?v=-smIiKYnP7o  -smIiKYnP7o  48000.0
# 918         918  http://youtube.com/watch?v=94oLKH1OnyA  94oLKH1OnyA  44100.0
# 919         919  http://youtube.com/watch?v=L1aIM2Rhwl0  L1aIM2Rhwl0  48000.0
# 920         920  http://youtube.com/watch?v=D2DGEaDxlok  D2DGEaDxlok  48000.0
# 921         921  http://youtube.com/watch?v=ggler84cbzk  ggler84cbzk  48000.0
# 922         922  http://youtube.com/watch?v=uZdaS5YiJG8  uZdaS5YiJG8  48000.0
# 923         923  http://youtube.com/watch?v=98rZ0n94Nm8  98rZ0n94Nm8  44100.0
# 924         924  http://youtube.com/watch?v=mGPmXURlOXU  mGPmXURlOXU  48000.0
# 925         925  http://youtube.com/watch?v=wGzWuz25ROM  wGzWuz25ROM  48000.0
# 926         926  http://youtube.com/watch?v=gOb-EjyXRPQ  gOb-EjyXRPQ  48000.0
# 927         927  http://youtube.com/watch?v=qaF9T5pCAfI  qaF9T5pCAfI  44100.0
# 929         929  http://youtube.com/watch?v=_1HnkNVy2rM  _1HnkNVy2rM  48000.0
# 930         930  http://youtube.com/watch?v=LRwYOOSMdeY  LRwYOOSMdeY  44100.0
# 931         931  http://youtube.com/watch?v=NNC10hQ_XNs  NNC10hQ_XNs  44100.0
# 932         932  http://youtube.com/watch?v=66nXF0wNfdg  66nXF0wNfdg  44100.0
#
#            time  wav_dims
# 0     2824192.0       2.0
# 1     6244065.0       2.0
# 2     5293056.0       2.0
# 3    12353536.0       2.0
# 4    10487744.0       2.0
# 5     6250496.0       2.0
# 6     8290394.0       2.0
# 7     8224768.0       2.0
# 8     2679808.0       2.0
# 9     9186498.0       2.0
# 10   13832192.0       2.0
# 11   14077735.0       2.0
# 12   13684736.0       2.0
# 13    9344576.0       2.0
# 14   11595615.0       2.0
# 16   20883225.0       2.0
# 17   11724800.0       2.0
# 18   10521792.0       2.0
# 19   19187983.0       2.0
# 21    9744892.0       2.0
# 23   10117154.0       2.0
# 24    8615936.0       2.0
# 25   22070787.0       2.0
# 28   15352832.0       2.0
# 29    9014856.0       2.0
# 30    8979190.0       2.0
# 32   10087061.0       2.0
# 33    8450890.0       2.0
# 34    8247616.0       2.0
# 35    7589568.0       2.0
# ..          ...       ...
# 899  12801024.0       2.0
# 900   5606400.0       2.0
# 901  11935744.0       2.0
# 902   6275273.0       2.0
# 903   9448419.0       2.0
# 906   9148603.0       2.0
# 907  10447063.0       2.0
# 908   9950527.0       2.0
# 909  11139203.0       2.0
# 911  10406080.0       2.0
# 912   8249344.0       2.0
# 913   6723325.0       2.0
# 914  15105357.0       2.0
# 915  10860007.0       2.0
# 916  11475968.0       2.0
# 917  12388623.0       2.0
# 918   9797632.0       2.0
# 919   9918763.0       2.0
# 920   8161105.0       2.0
# 921   7105619.0       2.0
# 922   9384332.0       2.0
# 923   8330560.0       2.0
# 924   1893389.0       2.0
# 925   8583522.0       2.0
# 926  13736123.0       2.0
# 927  13100032.0       2.0
# 929  12186888.0       2.0
# 930   9344448.0       2.0
# 931   8043520.0       2.0
# 932   8382464.0       2.0
#
# [783 rows x 6 columns]

# %%
songs.shape
# Out:
# (933,)
